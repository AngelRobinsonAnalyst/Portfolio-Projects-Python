# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # TASK 1
# Load the data into a Pandas DataFrame.

# %%
data = pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# #
# Identify the number of rows and columns and check if there are any null values in the given data.

# %%
#USE .info() TO DISPLAY INFORMATION ABOUT THE DATA SET
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # TASK 2
# Display the list of female customers who are self-employed and have an income of more than $4,000.

# %%
# CREATE THE VARIABLE data_female TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_female = data[(data.Gender == "Female")&(data.Self_Employed == 'Yes')&(data.ApplicantIncome > 4000)]

# DISPLAY THE FEMALES THAT MEET THE CRITERIA
data_female
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# # TASK 3
# Identify those male customers who hold a graduate degree and have the loan status as 'Y' (yes).

# %%
# CREATE THE VARIABLE data_male TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_male = data[(data.Gender == "Male")&(data.Education == "Graduate")&(data.Loan_Status == "Y")]

# %% [markdown]
# #
# Display the information of these customers.

# %%
# DISPLAY THE MALES THAT MEET THE CRITERIA
data_male
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %% [markdown]
# #
# Display the count of these customers.

# %%
# CREATE A VARIABLE male_index TO STORE THE INDICES OF THE MALES THAT MEET THE CRITERIA
male_index = data_male.index

# DISPLAY THE COUNT OF MALES BY USING print() AND .size TO EXTRACT THE COUNT OF THE INDICES(customers)
print(f"There are {male_index.size} males that meet this criteria")
# Out:
# There are 279 males that meet this criteria

# %% [markdown]
# # TASK 4
# Calculate the number of customers who have the loan status as 'Y', three or more dependents, and a property in a rural area.

# %%
# CREATE A VARIABLE data_rural TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_rural = data[(data.Loan_Status == "Y")&(data.Dependents >= "3")&(data.Property_Area == "Rural")]

# %%
# CREATE A VARIABLE rural_index TO STORE THE INDICES OF THE CUSTOMERS THAT MEET THE CRITERIA
rural_index = data_rural.index

# DISPLAY THE COUNT OF CUSTOMERS BY USING print() AND .size TO EXTRACT THE COUNT OF THE INDICES (customers)
print(f"There are {rural_index.size} customers that meet this criteria")
# Out:
# There are 13 customers that meet this criteria

# %% [markdown]
# #
# Display all the details of such customers.

# %%
# DISPLAY THE CUSTOMERS THAT MEET THE CRITERIA
data_rural
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# # TASK 5
# A new customer, Warner Kim, has applied for a loan of $290,000. Warner Kim is a graduate and owns a property in an urban area. Check whether Warner Kim would get his loan approved or not.

# %%
# CREATE A VARIABLE data_qualify TO DECIDE IF A CUSTOMER WITH THIS CRITERIA WOULD BE ACCEPTED FOR A LOAN
data_qualify = data[
    (data.LoanAmount >= 290)&(data.Education == "Graduate")&(data.Property_Area == "Urban")&
(data.Loan_Status == "Y")]
data_qualify.sort_values(['LoanAmount'],ascending = False)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 171  LP001585   Male     Yes         3+  Graduate            No
# 130  LP001469   Male      No          0  Graduate           Yes
# 333  LP002101   Male     Yes          0  Graduate            No
# 506  LP002624   Male     Yes          0  Graduate            No
# 260  LP001865   Male     Yes          1  Graduate            No
# 536  LP002734   Male     Yes          0  Graduate            No
# 21   LP001046   Male     Yes          1  Graduate            No
# 67   LP001233   Male     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0         700               300
# 130            20166                0.0         650               480
# 333            63337                0.0         490               180
# 506            20833             6667.0         480               360
# ...

# %% [markdown]
# # TASK 6
# Identify the customers who are not married, are self-employed, live in a nonurban area, and have their loan status as 'N'.

# %%
# CREATE A VARIABLE data_nonrural TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_nonrural = data[(data.Married == "No")&(data.Self_Employed == "Yes")&(data.Property_Area != "Urban")&(data.Loan_Status == "N")]

# DISPLAY THE MALES THAT MEET THE CRITERIA
data_nonrural
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
# 286             2600             1717.0          99               300
# 404             7441                0.0         194               360
# ...

# %% [markdown]
# #
# Calculate and display the gender-wise count of such customers.

# %%
# CREATE A VARIABLE data_nonrural_f TO EXTRACT THE FEMALE CUSTOMERS THAT MEET THE CRITERIA
data_nonrural_f = data_nonrural[(data.Gender == "Female")]

# CREATE A VARIABLE nonrural_findex TO STORE THE INDICES OF THE FEMALES THAT MEET THE CRITERIA
nonrural_findex = data_nonrural_f.index


# CREATE A VARIABLE data_nonrural_m TO EXTRACT THE MALE CUSTOMERS THAT MEET THE CRITERIA
data_nonrural_m = data_nonrural[(data.Gender =="Male")]

# CREATE A VARIABLE nonrural_mindex TO STORE THE INDICES OF THE MALES THAT MEET THE CRITERIA
nonrural_mindex = data_nonrural_m.index

# DISPLAY THE COUNT OF CUSTOMERS BY USING print() AND .size TO EXTRACT THE COUNT OF THE INDICES (male and female customers)
print(f"There are {nonrural_findex.size} females and {nonrural_mindex.size} males who meet this criteria")
# Out:
# There are 4 females and 3 males who meet this criteria

# %% [markdown]
# # TASK 7
# Calculate and display the average income of customers based on each area where their property is located (urban, semiurban, rural).

# %%
# CREATE A VARIABLE avg_income_by_area AND USED .groupby() AND .mean() TO EXTRACT THE AVERAGE INCOMES PER PROPERTY AREA
avg_income_by_area = data.groupby('Property_Area')['ApplicantIncome'].mean().reset_index()

# DISPLAY THE AVERAGE APPLICANT INCOMES PER PROPERTY AREA
avg_income_by_area
# Out:
#   Property_Area  ApplicantIncome
# 0         Rural      5554.083799
# 1     Semiurban      5292.261803
# 2         Urban      5398.247525

# %% [markdown]
# # TASK 8
# List the customers who have a property in a rural or semiurban area, applicant's income > $4,000, coapplicant's income > $1,000, and loan status is 'N'.

# %%
# CREATE A VARIABLE data_cust TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_cust = data[
    ((data.Property_Area == "Rural") | (data.Property_Area == "Semiurban"))&(data.ApplicantIncome > 4000)&
    (data.Loan_Status == "N")&(data.CoapplicantIncome > 1000)]

# DISPLAY THE CUSTOMERS THAT MEET THE CRITERIA
data_cust
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %% [markdown]
# #
# Count the number of such customers.

# %%
# CREATE A VARIABLE nonrural_findex TO STORE THE INDICES OF THE FEMALES THAT MEET THE CRITERIA
cust_index = data_cust.index

# DISPLAY THE COUNT OF CUSTOMERS BY USING print() AND .size TO EXTRACT THE COUNT OF THE INDICES 
print(f"There are {cust_index.size} applicants that meet this qualification")
# Out:
# There are 23 applicants that meet this qualification

# %% [markdown]
# #
# Update the loan status of such customers to 'Y'.

# %%
# CREATE A VARIABLE data_cust_dup TO ACT AS A COPY OF THE ORIGINAL DATA SET data_cust
data_cust_dup = data_cust

# CREATE A VARIABLE AND USE .replace() TO REPLACE THE "N" TO "Y"
# USE BRACKETS TO SELECT THE Loan_Status COLUMN
data_cust_dup['Loan_Status'] = data_cust['Loan_Status'].replace(['N'],"Y")

#CALL THE DATAFRAME TO DISPLAY ENSURE THAT THE .replace() WAS SUCCESSFUL
data_cust

# %% [markdown]
# #
# Redo the same task to verify that the count of such customers is now zero (after updating the loan status to 'Y').

# %%
#REASSIGN THE VARIABLE TO THE SAME CONDITIONS TO VERIFY THAT THE ABOVE CODE WAS SUCCESSFUL
data_cust = data[
    ((data.Property_Area == "Rural") | (data.Property_Area == "Semiurban"))&(data.ApplicantIncome > 4000)&
    (data.Loan_Status == "N")&(data.CoapplicantIncome > 1000)]

data_cust.size

# %% [markdown]
# # TASK 9
# Display the average income and the count of customers who have 3+ dependents, live in an urban area, and have their loan status as 'Y'.

# %%
# CREATE A VARIABLE data__urban TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data__urban = data[
    (data.Dependents > "3")&(data.Property_Area == "Urban")&(data.Loan_Status == "Y")]

data__urban
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 61   LP001206   Male     Yes         3+      Graduate            No
# 68   LP001238   Male     Yes         3+  Not Graduate           Yes
# 171  LP001585   Male     Yes         3+      Graduate            No
# 267  LP001882   Male     Yes         3+      Graduate            No
# 295  LP001949   Male     Yes         3+      Graduate            No
# 461  LP002484   Male     Yes         3+      Graduate            No
# 531  LP002720   Male     Yes         3+      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 61              3029                0.0          99               360
# 68              7100                0.0         125                60
# 171            51763                0.0         700               300
# 267             4333             1811.0         160               360
# ...

# %%
# CREATE A VARIABLE avg_urban AND USE .mean() TO FIND THE AVERAGE APPLICANT INCOME FOR THE ABOVE CUSTOMERS
avg_urban = data__urban.ApplicantIncome.mean()

print("The average Applicant Income for these customers is: \n",avg_urban)
# Out:
# The average Applicant Income for these customers is:
#  11045.625

# %%
# CREATE A VARIABLE data__urbanindex TO STORE THE INDICES OF THE CUSTOMERS THAT MEET THE CRITERIA
data__urbanindex = data__urban.index

# DISPLAY THE COUNT OF CUSTOMERS BY USING print() AND .size TO EXTRACT THE COUNT OF THE INDICES 
print(f"There are {data__urbanindex.size} applicants that meet this criteria")
# Out:
# There are 8 applicants that meet this criteria

# %% [markdown]
# # TASK 10
# Display the list of customers who live in rural or semiurban areas with 3+ dependents and have an income that is more than the average income of the customers who live in an urban area

# %%
# CREATE A VARIABLE data_other TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_other = data[
    (data.Dependents > "3")&((data.Property_Area == "Rural")|(data.Property_Area == "Semiurban"))&(data.ApplicantIncome > avg_urban)]

data_other
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 34   LP001100   Male      No         3+  Graduate            No
# 126  LP001448   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 324  LP002065   Male     Yes         3+  Graduate            No
# 409  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 34             12500             3000.0         320               360
# 126            23803                0.0         370               360
# 155            39999                0.0         600               180
# 324            15000                0.0         300               360
# 409            81000                0.0         360               360
#
#      Credit_History Property_Area Loan_Status
# 34                1         Rural           N
# 126               1         Rural           Y
# ...

# %% [markdown]
# #
# What do you infer from this task? Can you infer an important parameter that the bank is using to approve loans?

# %%
# Credit History seems to be the parameter that is being used to approve loans
# It appears that if an applicant has no credit history they are more likely to be denied

# %%
approved = data[data.Loan_Status == "Y"]
approved_index = approved.index
approved_history = approved[approved.Credit_History == 1]
approved_history_index = approved_history.index
print("Total Applicants approved: \n",approved_index.size)
print(f"there are {approved_history_index.size} customers with credit history")

approved_nohistory = approved[approved.Credit_History == 0]
approved_nohistory_index = approved_nohistory.index
print(f"there are {approved_nohistory_index.size} customers with out credit history")
# Out:
# Total Applicants approved:
#  422
# there are 413 customers with credit history
# there are 9 customers with out credit history

# %%
denied = data[data.Loan_Status == "N"]
denied_index = denied.index
denied_history = denied[denied.Credit_History == 1]
denied_history_index = denied_history.index
print("Total Applicants denied: \n",denied_index.size)
print(f"there are {denied_history_index.size} customers with credit history")

denied_nohistory = denied[denied.Credit_History == 0]
denied_nohistory_index = denied_nohistory.index
print(f"there are {denied_nohistory_index.size} customers with out credit history")

#denied.sort_values(['ApplicantIncome'],ascending = False)
# Out:
# Total Applicants denied:
#  192
# there are 108 customers with credit history
# there are 84 customers with out credit history

# %% [markdown]
# ### Display the average applicant income of those customers who are from nonurban areas and have their loan status as 'Y'.

# %%
# CREATE A VARIABLE data_inc TO EXTRACT THE CUSTOMERS THAT MEET THE CRITERIA
data_inc = data[(data.Property_Area != "Urban")&(data.Loan_Status == "Y")]

# CREATE A VARIABLE data_inc_avg AND USE .mean() TO FIND THE AVERAGE APPLICANT INCOME FOR THE CUSTOMERS
data_inc_avg = data_inc["ApplicantIncome"].mean()

# DISPLAY THE AVERAGE APPLICANT INCOME OF THE CUSTOMERS
print("The average Applicant Income for these customers is: \n $",data_inc_avg)

# DISPLAY THE DATA FRAME OF QUALIFYING CUSTOMERS
data_inc
# Out:
# The average Applicant Income for these customers is:
#  $ 5165.809688581315
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 26   LP001068    Male     Yes          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate           Yes
# 33   LP001098    Male     Yes          0      Graduate            No
# 37   LP001112  Female     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...
